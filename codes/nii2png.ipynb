# %%
import matplotlib

matplotlib.use('TkAgg')
import nibabel as nib
import numpy as np

import os
import imageio

# %%
def nii_to_png(nii_path, img_save_path, axis):

#     if not os.path.exists(img_save_path):
#         os.makedirs(img_save_path)

    nii = nib.load(nii_path)
    nii_fdata = nii.get_fdata()
    nii_fdata = np.rot90(nii_fdata)

    foldername = axis
#     png_save_path = os.path.join(img_save_path, foldername)
#     if not os.path.exists(png_save_path):
#         os.mkdir(png_save_path)

    flag = 100
    if axis == 'x':
        (axis, y, z) = nii.shape
        flag = 0
    elif axis == 'y':
        (x, axis, z) = nii.shape
        flag = 1
    elif axis == 'z':
        (x, y, axis) = nii.shape
        flag = 2
    else:
        print("wrong axis")

    for i in range(axis):
        if flag == 0:
            slice = nii_fdata[i, :, :]
        elif flag == 1:
            slice = nii_fdata[:, i, :]
        elif flag == 2:
            slice = nii_fdata[:, :, i]

        imageio.imwrite(f"{img_save_path}.png", slice)
        
        # imageio.imwrite(os.path.join(img_save_path, '{}.png'.format(i)), slice)
        # imageio.imwrite(os.path.join(png_save_path, '{}.png'.format(i)), slice)

# %%
def all_nii_to_png(all_nii_path,all_image_save_path, axis):
    all_nii_path_list = os.listdir(all_nii_path)
    for i in range(len(all_nii_path_list)):
        nii_to_png(os.path.join(all_nii_path,all_nii_path_list[i]),os.path.join(all_image_save_path, all_nii_path_list[i]), axis)
        print("第{}个nii文件转换完成！".format(i))

# %%
# if __name__ == "__main__":
#     all_nii_path = r'C:\Users\86152\Desktop\GU\590-01\project\Corpus callosum and brain segmentation images\abide.cc.bvol.20150118\Caltech\0051457\session_1\anat_1'
#     all_image_save_path = r'C:\Users\86152\Desktop\GU\590-01\project\Corpus callosum and brain segmentation images\abide.cc.bvol.20150118\Caltech\0051457\session_1\anat_1\image'
#     all_nii_to_png(all_nii_path, all_image_save_path, 'z')

# %%
root = "../data/"
os.listdir(root)
# Out:
# ['Caltech',
#  'CMU_a',
#  'CMU_b',
#  'KKI',
#  'Leuven_1',
#  'Leuven_2',
#  'MaxMun_a',
#  'MaxMun_b',
#  'MaxMun_c',
#  'MaxMun_d',
#  'NYU',
#  'OHSU',
#  'Olin',
#  'Pitt',
#  'SBL',
#  'SDSU',
#  'Stanford',
#  'Trinity',
#  'UCLA_1',
#  'UCLA_2',
#  'UM_1',
#  'UM_2',
#  'USM',
#  'Yale']

# %%
root = "..\\data\\"
os.listdir(root)

# for university in os.listdir(root):
#     unipath = os.path.join(root, university)
#     for patient_ID in os.listdir(unipath):        
#         scan_path = f"{unipath}/{patient_ID}/session_1/anat_1/abide_msp.nii"
#         save_path = os.path.join(root, patient_ID)
#         all_nii_to_png(scan_path, save_path, 'z')
# Out:
# ['Caltech',
#  'CMU_a',
#  'CMU_b',
#  'KKI',
#  'Leuven_1',
#  'Leuven_2',
#  'MaxMun_a',
#  'MaxMun_b',
#  'MaxMun_c',
#  'MaxMun_d',
#  'NYU',
#  'OHSU',
#  'Olin',
#  'Pitt',
#  'SBL',
#  'SDSU',
#  'Stanford',
#  'Trinity',
#  'UCLA_1',
#  'UCLA_2',
#  'UM_1',
#  'UM_2',
#  'USM',
#  'Yale']

# %%
root = "..\\data\\"
os.listdir(root)

if not os.path.exists('../scans/'):
         os.makedirs('../scans/')
        
for university in os.listdir(root):
    unipath = os.path.join(root, university)
    print(os.listdir(unipath))
    for patient_ID in os.listdir(unipath):  
        # NAVIGATE
        temp = os.path.join(unipath, patient_ID)
        temp = os.path.join(temp, "session_1")
        temp = os.path.join(temp, "anat_1")
        
        # WRITE
        scan_path = os.path.join(temp, "abide_msp.nii")
        save_path = f"../scans/{patient_ID}"
        try:
            nii_to_png(scan_path, save_path, 'z')
        except:
            pass
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 705.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1209.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 930.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 796.0]. Convert image to uint8 prior to saving to suppress this warning.
# ['0051456', '0051457', '0051458', '0051459', '0051460', '0051461', '0051462', '0051463', '0051464', '0051465', '0051466', '0051467', '0051468', '0051469', '0051470', '0051471', '0051472', '0051473', '0051474', '0051475', '0051476', '0051477', '0051478', '0051479', '0051480', '0051481', '0051482', '0051483', '0051484', '0051485', '0051486', '0051487', '0051488', '0051489', '0051490', '0051491', '0051492', '0051493']
# ...
